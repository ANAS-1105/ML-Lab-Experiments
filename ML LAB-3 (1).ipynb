# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("study_hours.csv")
X = dataset.iloc[:, 0:1].values # Hours
y = dataset.iloc[:, 1].values # Marks

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2) # quadratic curve
X_poly = poly.fit_transform(X)

# %%
poly_reg = LinearRegression()
poly_reg.fit(X_poly, y)
y_poly = poly_reg.predict(X_poly)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 poly_reg = LinearRegression()
#       2 poly_reg.fit(X_poly, y)
#       3 y_poly = poly_reg.predict(X_poly)
#
# NameError: name 'LinearRegression' is not defined

# %%
# -------- Polynomial Regression --------
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2) # quadraƟc curve
X_poly = poly.fit_transform(X)

# %%
plt.scatter(X, y)
plt.plot(X, y_lin)
plt.plot(X, y_poly)
plt.xlabel("Hours Studied")
plt.ylabel("Marks")
plt.title("Linear vs Polynomial Regression")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 plt.scatter(X, y)
# ----> 2 plt.plot(X, y_lin)
#       3 plt.plot(X, y_poly)
#       4 plt.xlabel("Hours Studied")
#
# NameError: name 'y_lin' is not defined

# %%
from sklearn.metrics import r2_score
print("Linear R2 Score:", r2_score(y, y_lin))
print("Polynomial R2 Score:", r2_score(y, y_poly))
