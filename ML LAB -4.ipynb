# %%
import joblib
import numpy as np

# %%
model = joblib.load("car_buy_model.pkl")

# %%
# User input
age = int(input("Enter Age: "))
income = int(input("Enter Income (Lakhs): "))
credit = int(input("Enter Credit Score: "))
exp = int(input("Enter Years of Experience: "))
# Out:
# Enter Age:  21
# Enter Income (Lakhs):  34
# Enter Credit Score:  25
# Enter Years of Experience:  5

# %%
new_data = np.array([[age, income, credit, exp]])
predicƟon = model.predict(new_data)
# Out:
# C:\ANACONDA\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
if predicƟon[0] == 1:
print("PredicƟon: Person WILL buy a car ")
else:
print("PredicƟon: Person will NOT buy a car")
# Out:
#   Cell In[15], line 2
#     print("PredicƟon: Person WILL buy a car ")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1
